# %% [markdown]
# ## Gerekli Kütüphanelerin İmport Edilmesi

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp39-cp39-win_amd64.whl (10.6 MB)
#      ---------------------------------------- 10.6/10.6 MB 7.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\danya\anaconda3\envs\test\lib\site-packages (from scikit-learn) (1.23.1)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#      -------------------------------------- 301.2/301.2 kB 4.6 MB/s eta 0:00:00
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.0-cp39-cp39-win_amd64.whl (46.2 MB)
#      ---------------------------------------- 46.2/46.2 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Verilerin İçeri Alınması

# %%
df_customers = pd.read_csv('data/olist_customers_dataset.csv')
df_order_items = pd.read_csv('data/olist_order_items_dataset.csv')
df_orders = pd.read_csv('data/olist_orders_dataset.csv')
df_products = pd.read_csv('data/olist_products_dataset.csv')

# %% [markdown]
# ## Verilerin Temizlenmesi

# %% [markdown]
# ### Müşteri Tabloları

# %%
df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 5 columns]

# %%
df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# ### Sipariş Tablosu

# %%
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
df_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df_orders.shape
# Out:
# (99441, 8)

# %%
df_orders = df_orders.dropna()

# %%
df_orders.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
df_orders.shape
# Out:
# (96461, 8)

# %% [markdown]
# ### Sipariş İtems Tablosu

# %%
df_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 7 columns]

# %%
df_order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# ### Ürün Tablosu

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# 1                     44.0                       276.0                 1.0
# 2                     46.0                       250.0                 1.0
# 3                     27.0                       261.0                 1.0
# 4                     37.0                       402.0                 4.0
# ...                    ...                         ...                 ...
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# 1                1000.0               30.0               18.0
# 2                 154.0               18.0                9.0
# 3                 371.0               26.0                4.0
# 4                 625.0               20.0               17.0
# ...                 ...                ...                ...
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm
# 0                  14.0
# 1                  20.0
# 2                  15.0
# 3                  26.0
# 4                  13.0
# ...                 ...
# 32946              40.0
# 32947              16.0
# 32948              27.0
# 32949              20.0
# 32950               7.0
#
# [32951 rows x 9 columns]

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_products = df_products.dropna()

# %%
df_products.shape
# Out:
# (32340, 9)

# %%
df_products.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
df_customers_orders = df_customers.merge(df_orders, on='customer_id')
df_customers_orders
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 96456  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 96457  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 96458  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 96459  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 96460  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
#
# 18820   03e1c946c0ddfc58724ff262aef08dff  98dac6635aee4995d501a3972e047414
# 18821   03e1c946c0ddfc58724ff262aef08dff  98dac6635aee4995d501a3972e047414
# 18822   03e1c946c0ddfc58724ff262aef08dff  98dac6635aee4995d501a3972e047414
# 18823   03e1c946c0ddfc58724ff262aef08dff  98dac6635aee4995d501a3972e047414
# 18824   03e1c946c0ddfc58724ff262aef08dff  98dac6635aee4995d501a3972e047414
# ...                                  ...                               ...
# 104153  9571759451b1d780ee7c15012ea109d4  ce27a3cc3c8cc1ea79d11e561e9bebb6
# 104154  9571759451b1d780ee7c15012ea109d4  ce27a3cc3c8cc1ea79d11e561e9bebb6
# 104155  9571759451b1d780ee7c15012ea109d4  ce27a3cc3c8cc1ea79d11e561e9bebb6
# 104156  9571759451b1d780ee7c15012ea109d4  ce27a3cc3c8cc1ea79d11e561e9bebb6
# 104157  9571759451b1d780ee7c15012ea109d4  ce27a3cc3c8cc1ea79d11e561e9bebb6
#
#         shipping_limit_date  price  freight_value
# 18820   2017-10-18 04:26:49   20.7          16.11
# 18821   2017-10-18 04:26:49   20.7          16.11
# 18822   2017-10-18 04:26:49   20.7          16.11
# 18823   2017-10-18 04:26:49   20.7          16.11
# 18824   2017-10-18 04:26:49   20.7          16.11
# ...                     ...    ...            ...
# 104153  2017-08-30 14:30:23   98.7          14.44
# 104154  2017-08-30 14:30:23   98.7          14.44
# 104155  2017-08-30 14:30:23   98.7          14.44
# 104156  2017-08-30 14:30:23   98.7          14.44
# 104157  2017-08-30 14:30:23   98.7          14.44
#
# [156 rows x 14 columns]

# %%
# Öneri sistemi oluşturmak için gerekli kütüphaneleri içe aktarın
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# İlk olarak siparişler tablosundan gerekli bilgileri alın
orders_data = top_customer_data[['order_id', 'customer_id', 'product_id']]

# TfidfVectorizer kullanarak müşterilerin aldığı ürünlerin özellik vektörlerini oluşturun
vectorizer = TfidfVectorizer(tokenizer=lambda x: x, lowercase=False)
orders_data.loc[:, 'product_id_str'] = orders_data['product_id'].apply(lambda x: ' '.join(x))
tfidf_matrix = vectorizer.fit_transform(orders_data['product_id_str'])

# Cosine similarity kullanarak müşteriler arasındaki benzerliği hesaplayın
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Müşteriye öneri yapmak için bir fonksiyon tanımlayın
def get_recommendations(customer_id, cosine_sim=cosine_sim, customer_products=top_customer_data):
    if customer_id in customer_products['customer_id'].values:
        idx = customer_products[customer_products['customer_id'] == customer_id].index[0]
        
        # Cosine benzerlik skorunu alın
        sim_scores = list(enumerate(cosine_sim[idx]))
        
        # Benzerlik skorlarına göre sıralama yapın
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        
        # En çok benzer olan 5 müşteriyi alın (kendisi hariç)
        sim_scores = sim_scores[1:6]
        
        # Bu müşterilerin IDsini alın
        customer_indices = [i[0] for i in sim_scores]
        
        # Önerilecek müşterileri ve aldıkları ürünleri döndürün
        return customer_products['customer_id'].iloc[customer_indices]
    else:
        return "Müşteri bulunamadı."

# Örnek olarak, müşteriye öneri yapmak için bir müşteri ID'si verin
customer_id = '1fca14ff2861355f6e5f14306ff977a7'
recommended_customers = get_recommendations(customer_id)
print("Müşteriye Önerilen Müşteriler:")
print(recommended_customers)
# Out:
# Müşteriye Önerilen Müşteriler:
# Müşteri bulunamadı.
# C:\Users\danya\AppData\Local\Temp\ipykernel_26240\3971565745.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_data.loc[:, 'product_id_str'] = orders_data['product_id'].apply(lambda x: ' '.join(x))
# C:\Users\danya\anaconda3\envs\test\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
# Öneri sistemi oluşturmak için gerekli kütüphaneleri içe aktarın
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# İlk olarak siparişler tablosundan gerekli bilgileri alın
orders_data = top_customer_data[['order_id', 'customer_id', 'product_id']]

# TfidfVectorizer kullanarak müşterilerin aldığı ürünlerin özellik vektörlerini oluşturun
vectorizer = TfidfVectorizer(tokenizer=lambda x: x, lowercase=False)
orders_data['product_id_str'] = orders_data['product_id'].apply(lambda x: ' '.join(x))
tfidf_matrix = vectorizer.fit_transform(orders_data['product_id_str'])

# Cosine similarity kullanarak müşteriler arasındaki benzerliği hesaplayın
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Müşteriye öneri yapmak için bir fonksiyon tanımlayın
def get_recommendations(customer_id, cosine_sim=cosine_sim, customer_products=top_customer_data):
    # Müşterinin indeksini bulun
    idx = customer_products[top_customer_data['customer_id'] == customer_id].index[0]
    
    # Cosine benzerlik skorunu alın
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Benzerlik skorlarına göre sıralama yapın
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # En çok benzer olan 5 müşteriyi alın (kendisi hariç)
    sim_scores = sim_scores[1:6]
    
    # Bu müşterilerin IDsini alın
    customer_indices = [i[0] for i in sim_scores]
    
    # Önerilecek müşterileri ve aldıkları ürünleri döndürün
    return customer_products['customer_id'].iloc[customer_indices]

# Örnek olarak, müşteriye öneri yapmak için bir müşteri ID'si verin
customer_id = '1fca14ff2861355f6e5f14306ff977a7'
recommended_customers = get_recommendations(customer_id)
print("Müşteriye Önerilen Müşteriler:")
print(recommended_customers)
# Out:
# C:\Users\danya\AppData\Local\Temp\ipykernel_26240\264840022.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_data['product_id_str'] = orders_data['product_id'].apply(lambda x: ' '.join(x))
# C:\Users\danya\anaconda3\envs\test\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26240\264840022.py in <module>
#      37 # Örnek olarak, müşteriye öneri yapmak için bir müşteri ID'si verin
#      38 customer_id = '1fca14ff2861355f6e5f14306ff977a7'
# ---> 39 recommended_customers = get_recommendations(customer_id)
#      40 print("Müşteriye Önerilen Müşteriler:")
#      41 print(recommended_customers)
#
# ~\AppData\Local\Temp\ipykernel_26240\264840022.py in get_recommendations(customer_id, cosine_sim, customer_products)
#      18 def get_recommendations(customer_id, cosine_sim=cosine_sim, customer_products=top_customer_data):
#      19     # Müşterinin indeksini bulun
# ---> 20     idx = customer_products[top_customer_data['customer_id'] == customer_id].index[0]
#      21
#      22     # Cosine benzerlik skorunu alın
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    5387             # GH#44051 exclude bool, which would return a 2d ndarray
#    5388             key = com.cast_scalar_indexer(key)
# -> 5389             return getitem(key)
#    5390
#    5391         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
